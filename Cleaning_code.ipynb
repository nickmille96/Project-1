# %% [markdown]
# # Analysis

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store file pathe in variable
file_path = Path("Resources/TobaccoUseData.csv")

# %%
# Read datafile with the Pandas library
tobacco_data_df= pd.read_csv(file_path, encoding = "utf-8")
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_12772\3532913569.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   tobacco_data_df= pd.read_csv(file_path, encoding = "utf-8")

# %%
tobacco_data_df.head()
# Out:
#         YEAR LocationAbbr                     LocationDesc  \
# 0       2019           US  National Median (States and DC)
# 1       2019           NC                   North Carolina
# 2       2019           TN                        Tennessee
# 3  2018-2019           WY                          Wyoming
# 4  2018-2019           WY                          Wyoming
#
#                    TopicType                       TopicDesc  \
# 0  Tobacco Use – Survey Data              Cessation (Adults)
# 1  Tobacco Use – Survey Data  Smokeless Tobacco Use (Adults)
# 2  Tobacco Use – Survey Data  Smokeless Tobacco Use (Adults)
# 3  Tobacco Use – Survey Data          Cigarette Use (Adults)
# 4  Tobacco Use – Survey Data          Cigarette Use (Adults)
#
#                                     MeasureDesc DataSource Response  \
# 0  Percent of Former Smokers Among Ever Smokers      BRFSS      NaN
# 1                                   Current Use      BRFSS      NaN
# ...

# %%
tobacco_data_df.count()
# Out:
# YEAR                          43341
# LocationAbbr                  43341
# LocationDesc                  43341
# TopicType                     43341
# TopicDesc                     43341
# MeasureDesc                   43341
# DataSource                    43341
# Response                      15018
# Data_Value_Unit               43341
# Data_Value_Type               43341
# Data_Value                    41224
# Data_Value_Footnote_Symbol     2117
# Data_Value_Footnote            2117
# Data_Value_Std_Err            41146
# Low_Confidence_Limit          41146
# High_Confidence_Limit         41146
# Sample_Size                   41146
# Gender                        43341
# Race                          43341
# Age                           43341
# Education                     43341
# GeoLocation                   43263
# TopicTypeId                   43341
# TopicId                       43341
# MeasureId                     43341
# StratificationID1             43341
# ...

# %%
# Clean the data and create the dataframe
clean_data_df = pd.DataFrame(tobacco_data_df[["YEAR","LocationDesc","TopicDesc","MeasureDesc","Response", "Data_Value", "Sample_Size", "Gender", "Race", "Age"]])
clean_data_df
# Out:
#             YEAR                     LocationDesc  \
# 0           2019  National Median (States and DC)
# 1           2019                   North Carolina
# 2           2019                        Tennessee
# 3      2018-2019                          Wyoming
# 4      2018-2019                          Wyoming
# ...          ...                              ...
# 43336       2011                       California
# 43337       2011                           Nevada
# 43338       2011                        Tennessee
# 43339       2012                        Tennessee
# 43340       2011                           Kansas
#
#                             TopicDesc  \
# 0                  Cessation (Adults)
# 1      Smokeless Tobacco Use (Adults)
# 2      Smokeless Tobacco Use (Adults)
# 3              Cigarette Use (Adults)
# 4              Cigarette Use (Adults)
# ...                               ...
# 43336          Cigarette Use (Adults)
# 43337  Smokeless Tobacco Use (Adults)
# ...

# %%
# Filter the Race column by "All Races"
clean_data_df = clean_data_df.loc[clean_data_df["Race"] == "All Races"]
clean_data_df
# Out:
#        YEAR                     LocationDesc                       TopicDesc  \
# 0      2019  National Median (States and DC)              Cessation (Adults)
# 13     2019                    New Hampshire          Cigarette Use (Adults)
# 14     2019                          Florida          Cigarette Use (Adults)
# 15     2019                           Hawaii  Smokeless Tobacco Use (Adults)
# 16     2019                          Alabama  Smokeless Tobacco Use (Adults)
# ...     ...                              ...                             ...
# 43336  2011                       California          Cigarette Use (Adults)
# 43337  2011                           Nevada  Smokeless Tobacco Use (Adults)
# 43338  2011                        Tennessee  Smokeless Tobacco Use (Adults)
# 43339  2012                        Tennessee  Smokeless Tobacco Use (Adults)
# 43340  2011                           Kansas          Cigarette Use (Adults)
#
# ...

# %%
# Reset the index
clean_data_df.reset_index(drop = True, inplace = True)

# %%
# Print the Clean DataFrame
clean_data_df
# Out:
#        YEAR                     LocationDesc                       TopicDesc  \
# 0      2019  National Median (States and DC)              Cessation (Adults)
# 1      2019                    New Hampshire          Cigarette Use (Adults)
# 2      2019                          Florida          Cigarette Use (Adults)
# 3      2019                           Hawaii  Smokeless Tobacco Use (Adults)
# 4      2019                          Alabama  Smokeless Tobacco Use (Adults)
# ...     ...                              ...                             ...
# 33201  2011                       California          Cigarette Use (Adults)
# 33202  2011                           Nevada  Smokeless Tobacco Use (Adults)
# 33203  2011                        Tennessee  Smokeless Tobacco Use (Adults)
# 33204  2012                        Tennessee  Smokeless Tobacco Use (Adults)
# 33205  2011                           Kansas          Cigarette Use (Adults)
#
# ...

# %%
clean_data_df.to_csv(".\Resources\Clean_Tobacco_data.csv")
