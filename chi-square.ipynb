# %%
# Import dependencies
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
# Read in csv file
tobacco_data = pd.read_csv("./Resources/Clean_Tobacco_data.csv")

tobacco_data.head()
# Out:
#    Unnamed: 0  YEAR                     LocationDesc  \
# 0           0  2019  National Median (States and DC)
# 1           1  2019                    New Hampshire
# 2           2  2019                          Florida
# 3           3  2019                           Hawaii
# 4           4  2019                          Alabama
#
#                         TopicDesc  \
# 0              Cessation (Adults)
# 1          Cigarette Use (Adults)
# 2          Cigarette Use (Adults)
# 3  Smokeless Tobacco Use (Adults)
# 4  Smokeless Tobacco Use (Adults)
#
#                                     MeasureDesc     Response  Data_Value  \
# 0  Percent of Former Smokers Among Ever Smokers          NaN        60.8
# 1                             Smoking Frequency    Every Day        76.3
# 2                               Current Smoking          NaN        14.8
# 3                                   Current Use          NaN         2.1
# 4                                   User Status  Not Current        88.6
#
#    Sample_Size   Gender       Race             Age
# 0          NaN  Overall  All Races        All Ages
# 1        357.0   Female  All Races        All Ages
# 2      15824.0  Overall  All Races        All Ages
# 3        459.0  Overall  All Races  18 to 24 Years
# 4       2729.0     Male  All Races        All Ages

# %%
# Remove Unnamed column
tobacco_data = tobacco_data[["YEAR", "LocationDesc", "TopicDesc", "MeasureDesc", "Response", "Data_Value", 
                            "Sample_Size", "Gender", "Race", "Age"]]

# %%
year_data = tobacco_data.loc[tobacco_data["YEAR"] == 2019]

year_data
# Out:
#       YEAR                     LocationDesc                       TopicDesc  \
# 0     2019  National Median (States and DC)              Cessation (Adults)
# 1     2019                    New Hampshire          Cigarette Use (Adults)
# 2     2019                          Florida          Cigarette Use (Adults)
# 3     2019                           Hawaii  Smokeless Tobacco Use (Adults)
# 4     2019                          Alabama  Smokeless Tobacco Use (Adults)
# ...    ...                              ...                             ...
# 3235  2019                        Louisiana  Smokeless Tobacco Use (Adults)
# 3236  2019                         Missouri          Cigarette Use (Adults)
# 3237  2019                        Wisconsin  Smokeless Tobacco Use (Adults)
# 3238  2019                            Idaho  Smokeless Tobacco Use (Adults)
# 3239  2019                           Oregon  Smokeless Tobacco Use (Adults)
#
#                                        MeasureDesc     Response  Data_Value  \
# 0     Percent of Former Smokers Among Ever Smokers          NaN        60.8
# 1                                Smoking Frequency    Every Day        76.3
# 2                                  Current Smoking          NaN        14.8
# 3                                      Current Use          NaN         2.1
# 4                                      User Status  Not Current        88.6
# ...                                            ...          ...         ...
# 3235                                   User Status  Not Current        94.2
# 3236                             Smoking Frequency    Every Day        74.4
# 3237                                   Current Use          NaN         5.0
# 3238                                   Current Use          NaN         4.4
# 3239                                   User Status      Current         5.6
#
#       Sample_Size   Gender       Race               Age
# 0             NaN  Overall  All Races          All Ages
# 1           357.0   Female  All Races          All Ages
# 2         15824.0  Overall  All Races          All Ages
# 3           459.0  Overall  All Races    18 to 24 Years
# 4          2729.0     Male  All Races          All Ages
# ...           ...      ...        ...               ...
# 3235       4467.0  Overall  All Races          All Ages
# 3236       1219.0  Overall  All Races          All Ages
# 3237        936.0  Overall  All Races    25 to 44 Years
# 3238       3357.0  Overall  All Races  Age 25 and Older
# 3239       2845.0     Male  All Races          All Ages
#
# [3240 rows x 10 columns]

# %%
male_data = year_data.loc[year_data["Gender"] == "Male"]

male_data.head()
# Out:
#     YEAR    LocationDesc                       TopicDesc  \
# 4   2019         Alabama  Smokeless Tobacco Use (Adults)
# 13  2019  North Carolina          Cigarette Use (Adults)
# 14  2019            Guam          Cigarette Use (Adults)
# 18  2019          Nevada          Cigarette Use (Adults)
# 33  2019         Vermont              Cessation (Adults)
#
#                                      MeasureDesc     Response  Data_Value  \
# 4                                    User Status  Not Current        88.6
# 13                                Smoking Status      Current        20.7
# 14                             Smoking Frequency    Some Days        28.4
# 18                             Smoking Frequency    Some Days        38.6
# 33  Percent of Former Smokers Among Ever Smokers          NaN        65.8
#
#     Sample_Size Gender       Race       Age
# 4        2729.0   Male  All Races  All Ages
# 13       1909.0   Male  All Races  All Ages
# 14        236.0   Male  All Races  All Ages
# 18        211.0   Male  All Races  All Ages
# 33       1389.0   Male  All Races  All Ages

# %%
mcig_data = male_data.loc[male_data["TopicDesc"] == "Cigarette Use (Adults)"]

mcig_data
# Out:
#       YEAR    LocationDesc               TopicDesc        MeasureDesc  \
# 13    2019  North Carolina  Cigarette Use (Adults)     Smoking Status
# 14    2019            Guam  Cigarette Use (Adults)  Smoking Frequency
# 18    2019          Nevada  Cigarette Use (Adults)  Smoking Frequency
# 40    2019           Maine  Cigarette Use (Adults)     Smoking Status
# 52    2019       Minnesota  Cigarette Use (Adults)  Smoking Frequency
# ...    ...             ...                     ...                ...
# 3172  2019      California  Cigarette Use (Adults)  Smoking Frequency
# 3190  2019        Virginia  Cigarette Use (Adults)  Smoking Frequency
# 3198  2019         Florida  Cigarette Use (Adults)     Smoking Status
# 3211  2019     Mississippi  Cigarette Use (Adults)     Smoking Status
# 3221  2019     Connecticut  Cigarette Use (Adults)  Smoking Frequency
#
#        Response  Data_Value  Sample_Size Gender       Race       Age
# 13      Current        20.7       1909.0   Male  All Races  All Ages
# 14    Some Days        28.4        236.0   Male  All Races  All Ages
# 18    Some Days        38.6        211.0   Male  All Races  All Ages
# 40       Former        32.3       4652.0   Male  All Races  All Ages
# 52    Every Day        72.1       1094.0   Male  All Races  All Ages
# ...         ...         ...          ...    ...        ...       ...
# 3172  Every Day        54.2        678.0   Male  All Races  All Ages
# 3190  Some Days        30.1        591.0   Male  All Races  All Ages
# 3198      Never        54.8       7178.0   Male  All Races  All Ages
# 3211      Never        49.4       1982.0   Male  All Races  All Ages
# 3221  Some Days        31.7        447.0   Male  All Races  All Ages
#
# [318 rows x 10 columns]

# %%
mresponse_data = mcig_data.loc[(mcig_data["Response"] == "Current") | (mcig_data["Response"] == "Former")]

mresponse_data
# Out:
#       YEAR    LocationDesc               TopicDesc     MeasureDesc Response  \
# 13    2019  North Carolina  Cigarette Use (Adults)  Smoking Status  Current
# 40    2019           Maine  Cigarette Use (Adults)  Smoking Status   Former
# 82    2019        Virginia  Cigarette Use (Adults)  Smoking Status   Former
# 121   2019   Massachusetts  Cigarette Use (Adults)  Smoking Status   Former
# 134   2019        Maryland  Cigarette Use (Adults)  Smoking Status  Current
# ...    ...             ...                     ...             ...      ...
# 3040  2019    Pennsylvania  Cigarette Use (Adults)  Smoking Status   Former
# 3073  2019        Delaware  Cigarette Use (Adults)  Smoking Status  Current
# 3085  2019  South Carolina  Cigarette Use (Adults)  Smoking Status  Current
# 3104  2019        Missouri  Cigarette Use (Adults)  Smoking Status   Former
# 3157  2019     Puerto Rico  Cigarette Use (Adults)  Smoking Status   Former
#
#       Data_Value  Sample_Size Gender       Race       Age
# 13          20.7       1909.0   Male  All Races  All Ages
# 40          32.3       4652.0   Male  All Races  All Ages
# 82          26.0       4249.0   Male  All Races  All Ages
# 121         26.3       3409.0   Male  All Races  All Ages
# 134         14.2       7239.0   Male  All Races  All Ages
# ...          ...          ...    ...        ...       ...
# 3040        30.1       3098.0   Male  All Races  All Ages
# 3073        15.8       1651.0   Male  All Races  All Ages
# 3085        19.5       3096.0   Male  All Races  All Ages
# 3104        30.2       3108.0   Male  All Races  All Ages
# 3157        23.7       2222.0   Male  All Races  All Ages
#
# [106 rows x 10 columns]

# %%
male_mean = mresponse_data["Sample_Size"].mean()

male_mean
# Out:
# 3484.826923076923
